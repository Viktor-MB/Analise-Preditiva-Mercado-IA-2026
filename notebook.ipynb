# %% [markdown]
# ## 1. Objetivo da Pesquisa

# %% [markdown]
# - Este projeto tem como propósito realizar uma investigação profunda no mercado de trabalho global voltado para Inteligência Artificial e Ciência de Dados, cobrindo o período de transformação acelerada entre 2020 e 2026.

# %% [markdown]
# ## 2. Coleta dos dados

# %%
# %pip install matplotlib seaborn --quiet

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Carregar o dataset
df = pd.read_csv('./dados/AI Job Market Dataset.csv')

df.head(10)
# Out:
# Note: you may need to restart the kernel to use updated packages.
#    job_id                  job_title company_size company_industry    country  \
# 0       1                AI Engineer      Startup           Retail     Canada
# 1       2  Machine Learning Engineer          MNC       Technology  Australia
# 2       3  Machine Learning Engineer          MNC       Technology    Germany
# 3       4           Business Analyst      Startup       Healthcare    Germany
# 4       5             Data Scientist          MNC       Healthcare    Germany
# 5       6  Machine Learning Engineer       Medium       Technology  Australia
# 6       7             Data Scientist          MNC       Technology    Germany
# 7       8               Data Analyst   Enterprise          Finance         UK
# 8       9  Machine Learning Engineer      Startup        Education     Canada
# 9      10              Data Engineer   Enterprise           Retail        USA
#
# ...

# %% [markdown]
# ## Divisão dos dados

# %%
from sklearn.model_selection import train_test_split

# Dividir o dataset em conjunto de trabalho (80%) e conjunto de validação (20%), para evitar vazamento de dados e overfitting
df_trabalho, df_validacao = train_test_split(df, test_size=0.2, random_state=42)
print(df_trabalho.shape)
print(df_validacao.shape)
# Out:
# (8276, 19)
# (2069, 19)
